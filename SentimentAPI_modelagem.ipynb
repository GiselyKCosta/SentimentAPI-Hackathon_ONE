# %% [markdown]
# <a href="https://colab.research.google.com/github/GiselyKCosta/SentimentAPI-Hackathon_ONE/blob/modelagem/SentimentAPI_modelagem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## EDA

# %% [markdown]
# ##TF-IDF

# %% [markdown]
# ## Treinamento
